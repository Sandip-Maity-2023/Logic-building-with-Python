# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('students_marks.csv')

# Function to calculate internal marks
def calculate_internal_marks(row):
    # Fetch all test marks
    tests = [row['Class Test 1'], row['Class Test 2'], row['Class Test 3'], row['Class Test 4']]
    attendance = row['Attendance']
    grade = row['Overall Class Grade'] if pd.notnull(row['Overall Class Grade']) else 'C'  # Default grade to 'C' if missing

    # Condition 1: Debarred if attendance < 75
    if attendance < 75:
        return "Debarred"

    # Process absent tests (0 marks) as per conditions
    adjusted_tests = []
    for test in tests:
        if test == 0:
            if attendance >= 85:
                # Replace based on Grade for >=85% attendance
                if grade == 'A':
                    adjusted_tests.append(18)
                elif grade == 'B':
                    adjusted_tests.append(17)
                else:  # Grade C
                    adjusted_tests.append(16)
            elif 75 <= attendance < 85:
                # Replace based on Grade for >=75% and <85% attendance
                if grade == 'A':
                    adjusted_tests.append(16)
                elif grade == 'B':
                    adjusted_tests.append(15)
                else:  # Grade C
                    adjusted_tests.append(14)
        else:
            adjusted_tests.append(test)

    # Select the best 3 tests after adjustment
    tests_sorted = sorted(adjusted_tests, reverse=True)
    best_3_tests = tests_sorted[:3]
    test_avg = sum(best_3_tests) / 3

    # Scale Class Test Marks to 40
    test_marks = (test_avg / 20) * 40  # Test component is out of 40

    # Attendance Marks Calculation (Max 5)
    if attendance >= 80:
        attendance_marks = 5
    elif attendance >= 75:
        attendance_marks = 3
    else:
        attendance_marks = 2

    # Class Performance Marks based on Grade (Max 5)
    grade_performance_marks = {'A': 5, 'B': 4, 'C': 3}
    performance_marks = grade_performance_marks.get(grade, 3)

    # Total Internal Marks out of 50
    internal_marks = test_marks + attendance_marks + performance_marks
    return round(internal_marks, 2)

# Apply the function to each student
df['Internal Marks (out of 50)'] = df.apply(calculate_internal_marks, axis=1)

# Export result to a new CSV file (optional)
df.to_csv('Final_Internal_Marks.csv', index=False)

# Print the output for review
print(df[['Name', 'Roll','Class Test 1','Class Test 2','Class Test 3','Class Test 4','Attendance','Overall Class Grade', 'Internal Marks (out of 50)']])
# Out:
#         Name                      Roll  Class Test 1  Class Test 2  \
# 0     Atharv  UG/02/BTCSEAIML/2023/027            16            19
# 1     Yuvaan  UG/02/BTCSEAIML/2023/665            16             0
# 2      Meera  UG/02/BTCSEAIML/2023/574            18            16
# 3    Shanaya  UG/02/BTCSEAIML/2023/825            15            18
# 4     Amaira  UG/02/BTCSEAIML/2023/828            16             0
# 5      Harsh  UG/02/BTCSEAIML/2023/063            19            10
# 6      Ayush  UG/02/BTCSEAIML/2023/890            13            12
# 7     Advait  UG/02/BTCSEAIML/2023/003            15             8
# 8      Advik  UG/02/BTCSEAIML/2023/284            17             0
# 9      Vanya  UG/02/BTCSEAIML/2023/344            19             6
# 10       Tia  UG/02/BTCSEAIML/2023/032            12            14
# 11    Ananya  UG/02/BTCSEAIML/2023/759            19            13
# 12    Vivaan  UG/02/BTCSEAIML/2023/025            17             8
# 13     Samar  UG/02/BTCSEAIML/2023/389             7            16
# 14     Navya  UG/02/BTCSEAIML/2023/225            16             7
# 15    Aadhya  UG/02/BTCSEAIML/2023/228            17             7
# 16  Rudraksh  UG/02/BTCSEAIML/2023/409            16             8
# 17    Saanvi  UG/02/BTCSEAIML/2023/250            12             9
# 18     Anika  UG/02/BTCSEAIML/2023/633            12            16
# 19    Simran  UG/02/BTCSEAIML/2023/708             9            12
# 20      Pari  UG/02/BTCSEAIML/2023/558            15             0
# 21     Aanya  UG/02/BTCSEAIML/2023/604             9            18
# 22    Ishaan  UG/02/BTCSEAIML/2023/288            15             7
# 23     Arnav  UG/02/BTCSEAIML/2023/781            18            19
# 24     Kiaan  UG/02/BTCSEAIML/2023/459            14             0
# 25    Ishita  UG/02/BTCSEAIML/2023/094            18            14
# 26      Zoya  UG/02/BTCSEAIML/2023/095             7            14
# 27      Diya   UG/02/BTCSEAIML/2023/74            14            10
# 28     Kabir  UG/02/BTCSEAIML/2023/482             9            11
# 29      Neil  UG/02/BTCSEAIML/2023/777            15             6
# 30      Arya  UG/02/BTCSEAIML/2023/220            19            10
# 31   Tanisha  UG/02/BTCSEAIML/2023/230            18            17
# 32    Vihaan  UG/02/BTCSEAIML/2023/767             8            11
# 33     Laksh  UG/02/BTCSEAIML/2023/429             5            19
# 34     Rudra  UG/02/BTCSEAIML/2023/089            12            16
# 35   Reyansh  UG/02/BTCSEAIML/2023/692             7            17
# 36     Aarav  UG/02/BTCSEAIML/2023/654            11            16
# 37      Jiya  UG/02/BTCSEAIML/2023/733             6            16
# 38     Dhruv  UG/02/BTCSEAIML/2023/030            12            13
# 39     Aryan  UG/02/BTCSEAIML/2023/754            11             9
# 40      Myra  UG/02/BTCSEAIML/2023/204            14            13
# 41     Eshan  UG/02/BTCSEAIML/2023/348            16            14
# 42     Arjun  UG/02/BTCSEAIML/2023/203            10            11
# 43    Aarohi  UG/02/BTCSEAIML/2023/758            11             6
# 44   Krishna  UG/02/BTCSEAIML/2023/432             8             6
# 45   Shaurya  UG/02/BTCSEAIML/2023/223            10             9
# 46      Riya  UG/02/BTCSEAIML/2023/603            10             5
# 47     Rohan  UG/02/BTCSEAIML/2023/537             0             0
# 48     Kiara  UG/02/BTCSEAIML/2023/238             9            16
# 49       Ira  UG/02/BTCSEAIML/2023/006             0             0
#
#     Class Test 3  Class Test 4  Attendance Overall Class Grade  \
# 0             16            19          77                   A
# 1             19             0          50                   C
# 2             17            18          74                   B
# 3             19            14          82                   B
# 4              0             0          57                   A
# 5             15            16          91                   B
# 6             16            19          76                   B
# 7             18            18          77                   C
# 8             12             0          55                   C
# 9             15            17          90                   A
# 10            19            12          77                   A
# 11             8            16          94                   B
# 12            18            13          88                   C
# 13            14            18          98                   A
# 14            13            19          90                   B
# 15            19            12          78                   A
# 16            12            19          64                   C
# 17            19            13          92                   C
# 18            16             9           0                   B
# 19            17            14          76                   A
# 20            12            12          51                   A
# 21            17             7          94                   A
# 22            18            11          64                   B
# 23             5             8          73                   C
# 24            11             0          52                   B
# 25             9             8          98                   A
# 26            12            15          93                   A
# 27             7            17          93                   B
# 28            12            16          85                   C
# 29            12            14          86                   A
# 30             7            11          81                   B
# 31             7             5          81                   A
# 32            14            14          72                   C
# 33             0            11          62                   A
# 34             9             9          91                   B
# 35            16             0          56                   A
# 36             6            11          86                   B
# 37            17             5          82                   C
# 38             9            10          77                   B
# 39            18             6          62                   C
# 40            11             5          81                   A
# 41             5             7          73                   B
# 42            13             7          88                   A
# 43            13            11          71                   C
# 44            11            16           0                   C
# 45             0             7          93                   A
# 46            12            11          88                   C
# 47             0             0           0                 NaN
# 48            14            15           0                   A
# 49             0             0           0                 NaN
#
#    Internal Marks (out of 50)
# 0                        44.0
# 1                    Debarred
# 2                    Debarred
# 3                       43.67
# 4                    Debarred
# 5                       42.33
# 6                        39.0
# 7                        40.0
# 8                    Debarred
# 9                        44.0
# 10                       38.0
# 11                       41.0
# 12                       40.0
# 13                       42.0
# 14                       41.0
# 15                       40.0
# 16                   Debarred
# 17                      37.33
# 18                   Debarred
# 19                      36.67
# 20                   Debarred
# 21                      39.33
# 22                   Debarred
# 23                   Debarred
# 24                   Debarred
# 25                      37.33
# 26                      37.33
# 27                      36.33
# 28                       34.0
# 29                      37.33
# 30                      35.67
# 31                       38.0
# 32                   Debarred
# 33                   Debarred
# 34                      33.67
# 35                   Debarred
# 36                      34.33
# 37                       34.0
# 38                      30.33
# 39                   Debarred
# 40                      35.33
# 41                   Debarred
# 42                      32.67
# 43                   Debarred
# 44                   Debarred
# 45                      34.67
# 46                       30.0
# 47                   Debarred
# 48                   Debarred
# 49                   Debarred
